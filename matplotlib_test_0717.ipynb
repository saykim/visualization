# %%
import numpy as np, pandas as pd
import matplotlib.pyplot as plt

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)
def g(t):
    return np.sin(np.pi*t)

t1 = np.arange(0.0, 5.0, 0.01)
t2 = np.arange(0.0, 5.5, 0.1)

#그래프

#plt.plot(t1, f(t1), t2, g(t2)) #하나의 틀에 2개 그래프 동시 생성

plt.subplots()
plt.figure(1)
plt.plot(t1, f(t1))
plt.figure(2)
plt.plot(t2, f(t2))
plt.figure(3)
plt.plot(t1, g(t1))
plt.figure(4)
plt.plot(t2, g(t2))

# %%
import seaborn as sns

# %%
sns.distplot(t2, bins=30)

# %% [markdown]
# # matplotlib 다중 그래프 그리기

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)
def g(t):
    return np.sin(np.pi*t)

t1 = np.arange(0.0, 5.0, 0.01)
t2 = np.arange(0.0, 5.0, 0.01)

#그래프

#plt.plot(t1, f(t1), t2, g(t2)) #하나의 틀에 2개 그래프 동시 생성

fig, ax = plt.subplots(2,1, constrained_layout=True, sharex=True)
ax[0].plot(t1, f(t1))
ax[1].plot(t2, g(t2))

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)
def g(t):
    return np.sin(np.pi*t)

t1 = np.arange(0.0, 5.0, 0.01)
t2 = np.arange(0.0, 3.5, 0.4)

#그래프

#plt.plot(t1, f(t1), t2, g(t2)) #하나의 틀에 2개 그래프 동시 생성

f, ax = plt.subplots(2,1, constrained_layout=True)
ax[0].plot(t1, f(t1))
ax[1].plot(t2, f(t2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-fa58f8c49997> in <module>
#      12
#      13 f, ax = plt.subplots(2,1, constrained_layout=True)
# ---> 14 ax[0].plot(t1, f(t1))
#      15 ax[1].plot(t2, f(t2))
#
# TypeError: 'Figure' object is not callable

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(211)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(212)
plt.plot(x2, y2, 'ko-')
plt.title('A tale of 2 subplots')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
# Out:
# Text(0, 0.5, 'Undamped')

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(221)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(222)
plt.plot(x2, y2, 'ko-')
plt.title('A tale of 2 subplots')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
# Out:
# Text(0, 0.5, 'Undamped')

# %%
# 2x2 형태의 네 개의 플롯
plt.subplot(221)
plt.plot(np.random.rand(5))
plt.subplot(222)
plt.plot(np.random.rand(5))
plt.subplot(223)
plt.plot(np.random.rand(5))
plt.subplot(224)
plt.plot(np.random.rand(5))

# %% [markdown]
# ### sunplots 으로 다중 그래프 그리기

# %%
f, ax = plt.subplots(2,2)
ax[0,0].plot(np.random.rand(5))
ax[0,0].set_title('axes 1')
ax[0,1].plot(np.random.rand(5))
ax[0,1].set_title('axes 2')
ax[1,0].plot(np.random.rand(5))
ax[1,0].set_title('axes 3')
ax[1,1].plot(np.random.rand(5))
ax[1,1].set_title('axes 4')
# Out:
# Text(0.5, 1.0, 'axes 4')

# %%
f, ax = plt.subplots(2,2, figsize=(12,5))
ax[0,0].plot(np.random.rand(30))
ax[0,1].plot(np.random.rand(30))
ax[1,0].plot(np.random.rand(30))
ax[1,1].plot(np.random.rand(30))

# %% [markdown]
# ## Multi Axes

# %%
f, ax0 = plt.subplots()
ax1 = ax0.twinx()

ax0.set_title('2 Axes')
ax0.plot([10,5,2,9,7], 'r-', label='y0')
ax0.set_ylabel('y0')
ax0.grid(False)
ax1.plot([100,200,435,500,150], 'g:', label='y1')
ax1.set_ylabel('y1')
f.legend()

# %% [markdown]
# ## matplotlib 여러가지

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y = [3,2,1]
x = np.arange(len(y))
xlabel = ['A','B', 'C']
plt.title('Bar Chart')
plt.bar(x,y, alpha=.6)
plt.xticks(x,xlabel)
#plt.yticks(sorted(y)) #오름차순
plt.yticks(y)
# Out:
# ([<matplotlib.axis.YTick at 0x13c269e8>,
# ...
#  <a list of 3 Text yticklabel objects>)

# %%
np.random.seed(0)
x=np.random.normal(0,1,100)
y=np.random.normal(0,1,100)
plt.style.use('seaborn-pastel')
plt.title('scatter plot')
plt.scatter(x,y)
plt.grid(True)

# %%
data = {'apples': 10, 'oranges': 15, 'lemons': 5, 'limes': 20}
names = list(data.keys())
values = list(data.values())

f, ax = plt.subplots(1,3, figsize=(9,3), sharex=False)
ax[0].bar(names, values)
ax[1].scatter(names, values)
ax[2].plot(names, values)

# %% [markdown]
# ## **Plotting**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

dt = 0.01
t = np.arange(0, 30, dt)
nse1 = np.random.randn(len(t))                 # white noise 1
nse2 = np.random.randn(len(t))                 # white noise 2

# Two signals with a coherent part at 10Hz and a random part
s1 = np.sin(2 * np.pi * 10 * t) + nse1
s2 = np.sin(2 * np.pi * 10 * t) + nse2

# %%
print(t)
print('-------------'*5)
print(nse1)
print('-------------'*5)
print(nse2)
# Out:
# [0.000e+00 1.000e-02 2.000e-02 ... 2.997e+01 2.998e+01 2.999e+01]
# -----------------------------------------------------------------
# [ 1.04930431  0.86609917  0.5511346  ... -1.03880531 -0.56047396
#  -0.95100945]
# -----------------------------------------------------------------
# [ 1.61546082  0.07466355 -0.92363036 ...  0.67095329  0.36549965
#  -0.12610051]

# %%
s1 = np.sin(2*np.pi*10*t) + nse1
s2 = np.sin(2*np.pi*10*t) + nse2

# %%
f, ax = plt.subplots(2,1)
ax[0].plot(t, s1, t, s2, alpha=.8)

# %%
f, ax = plt.subplots(2,1)
ax[0].plot(t, s1, t, s2, alpha=.8)
ax[0].set_xlim(0,2)
ax[0].set_xlabel('time')
ax[0].set_ylabel('s1 and s2')
ax[0].grid(True)

# %%
f, ax = plt.subplots(2,1)
ax[0].plot(t, s1, t, s2, alpha=.8)
ax[0].set_xlim(0,2)
ax[0].set_xlabel('time')
ax[0].set_ylabel('s1 and s2')
ax[0].grid(True)

cxy, f = ax[1].cohere(s1, s2, 256, 1./dt)
