# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

# %%
import numpy as np
import pandas as pd

# %%
f = plt.figure(figsize=(8,7))
ax1 = f.add_subplot(221)
ax1.hist(np.random.randn(100))

ax2 = f.add_subplot(222)
ax2.scatter(np.arange(30), np.arange(30)+6*np.random.rand(30))

ax3 = f.add_subplot(223)
ax3.plot(np.random.rand(50).cumsum())

ax4 = f.add_subplot(224)

# %%
data = pd.Series(np.random.randn(16))
data
# Out:
# 0     0.422940
# 1     1.593576
# 2    -0.100225
# 3    -0.249137
# 4     1.396918
# 5    -0.591309
# 6     2.104438
# 7     0.574980
# 8     0.014808
# 9    -0.042417
# 10    0.918402
# 11    0.377800
# 12   -1.186820
# 13    0.120005
# 14    0.193352
# 15   -0.383076
# dtype: float64

# %%
f, ax = plt.subplots(2,3)
data.plot(kind='bar', ax = ax[0,1])
data.plot(kind='bar', ax = ax[0,0], color = 'R')
